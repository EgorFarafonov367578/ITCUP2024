# %%
import pandas as pd
import numpy as np
print("Start")
df = pd.read_csv("https://raw.githubusercontent.com/EgorFarafonov367578/ITCUP2024/main/data_source/pos_general.csv")
print("Finish")
# Out:
# Start
# Finish

# %%
df['pos_sales_with_tax'].plot(kind='hist',bins=80)
# Out:
# <Axes: ylabel='Frequency'>
